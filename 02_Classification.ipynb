# %%
import numpy as np
import pandas as pd
from Packages.My_NLP import KNN_Calculation
from Packages.Common import clearScreen

# %%
clearScreen()

# Load Trained twitter dataset ( with sentiment class and somw keyword frequency as feauter)
reference_dataset = pd.read_csv('Exports/TwitterSentimentDataset.csv')
#Load sample tweet for classification
sample_dataset = pd.read_csv('Exports/Sample_Tweet.csv')

# %%
features_of_reference_dataset = reference_dataset.iloc[:, 2:]
features_of_sample_dataset = sample_dataset.iloc[:, 2:]
result = pd.DataFrame(columns=['Sentimental', 'cosinus_similarity'])

# %%
for sample_index, sample in features_of_sample_dataset.iterrows():
    for tweet_index, tweet in features_of_reference_dataset.iterrows():
        dotproduct_value = np.dot(tweet.to_numpy(), sample.to_numpy())
        norm_current_row = np.linalg.norm(tweet.to_numpy()) # calculate current row norm ( regarding to similarity formula )
        norm_sample = np.linalg.norm(sample.to_numpy()) # calculate sample data norm ( regarding to similarity formula )
        if (norm_current_row == 0 or norm_sample == 0): # prevent devide by zero exception
            cos = 0
        else:
            cos = dotproduct_value / (norm_current_row * norm_sample) # calculate cosinus similarity          
        result = result.append({'Sentimental': reference_dataset.at[tweet_index,"Sentimental"], 'cosinus_similarity': cos},ignore_index=True)
    
    print("*************************************** Base Information ***************************************")
    print("Text of Tweet: " , sample_dataset.at[sample_index,'Tweet'])
    print("Base Sentiment: " , sample_dataset.at[sample_index,'Sentimental'])
    print("================================")
    KNN_Calculation(result,5)  
    KNN_Calculation(result,20)
    KNN_Calculation(result,50)
    KNN_Calculation(result,100)
    result.drop(result.index, inplace=True)
    print("**********************************************************************************************")
# Out:
# *************************************** Base Information ***************************************
# Text of Tweet:  @rachelburden Have a fabulous time. Will miss you. :) xx
# Base Sentiment:  Positive
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  5
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 20 nearest neighbors
# Positive Class:  20
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 50 nearest neighbors
# Positive Class:  50
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 100 nearest neighbors
# Positive Class:  100
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  I do not know. I'm sorry !!
# :( https://t.co/3dQB9Pt3UY
# Base Sentiment:  Negative
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  0
# Negative Class:  5
# Pridicted Sentiment is: Negative
#
# Calculation based on 20 nearest neighbors
# Positive Class:  0
# Negative Class:  20
# Pridicted Sentiment is: Negative
#
# Calculation based on 50 nearest neighbors
# Positive Class:  0
# Negative Class:  50
# Pridicted Sentiment is: Negative
#
# Calculation based on 100 nearest neighbors
# Positive Class:  0
# Negative Class:  100
# Pridicted Sentiment is: Negative
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  @Cramdaline It just doesn't go away... you must go to the dentist. :( #poorKid
# Base Sentiment:  Negative
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  0
# Negative Class:  5
# Pridicted Sentiment is: Negative
#
# Calculation based on 20 nearest neighbors
# Positive Class:  0
# Negative Class:  20
# Pridicted Sentiment is: Negative
#
# Calculation based on 50 nearest neighbors
# Positive Class:  0
# Negative Class:  50
# Pridicted Sentiment is: Negative
#
# Calculation based on 100 nearest neighbors
# Positive Class:  0
# Negative Class:  100
# Pridicted Sentiment is: Negative
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  @LampeLois Please follow me, I will return it soon follow :) #TuitUtil http://t.co/Fw5JKPrVxt
# Base Sentiment:  Positive
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  5
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 20 nearest neighbors
# Positive Class:  20
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 50 nearest neighbors
# Positive Class:  50
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 100 nearest neighbors
# Positive Class:  100
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  Stats for the week have arrived. 1 new follower and NO unfollowers :) via http://t.co/knhEHfUJRs.
# Base Sentiment:  Positive
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  5
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 20 nearest neighbors
# Positive Class:  20
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 50 nearest neighbors
# Positive Class:  50
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 100 nearest neighbors
# Positive Class:  100
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  @cinghh @imvnaj @BahetiRidham party cancel :p #BajrangiBhaijaanHighestWeek1
# Base Sentiment:  Positive
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  1
# Negative Class:  4
# Pridicted Sentiment is: Negative
#
# Calculation based on 20 nearest neighbors
# Positive Class:  9
# Negative Class:  11
# Pridicted Sentiment is: Negative
#
# Calculation based on 50 nearest neighbors
# Positive Class:  24
# Negative Class:  26
# Pridicted Sentiment is: Negative
#
# Calculation based on 100 nearest neighbors
# Positive Class:  51
# Negative Class:  49
# Pridicted Sentiment is: Positive
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  Happy and wonderful birthday my love 💟 Have the most beautiful day in the world :)
# Base Sentiment:  Positive
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  5
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 20 nearest neighbors
# Positive Class:  20
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 50 nearest neighbors
# Positive Class:  50
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 100 nearest neighbors
# Positive Class:  100
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  Harry and niall and -94 (when harry was born) ik it's stupid and i wanna change it :D https://t.co/gHAt8ZDAfF
# Base Sentiment:  Positive
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  1
# Negative Class:  4
# Pridicted Sentiment is: Negative
#
# Calculation based on 20 nearest neighbors
# Positive Class:  9
# Negative Class:  11
# Pridicted Sentiment is: Negative
#
# Calculation based on 50 nearest neighbors
# Positive Class:  24
# Negative Class:  26
# Pridicted Sentiment is: Negative
#
# Calculation based on 100 nearest neighbors
# Positive Class:  51
# Negative Class:  49
# Pridicted Sentiment is: Positive
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  @TheLadyShelly haha I feel so naked without ole beardy tho :(
# Base Sentiment:  Negative
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  0
# Negative Class:  5
# Pridicted Sentiment is: Negative
#
# Calculation based on 20 nearest neighbors
# Positive Class:  0
# Negative Class:  20
# Pridicted Sentiment is: Negative
#
# Calculation based on 50 nearest neighbors
# Positive Class:  0
# Negative Class:  50
# Pridicted Sentiment is: Negative
#
# Calculation based on 100 nearest neighbors
# Positive Class:  0
# Negative Class:  100
# Pridicted Sentiment is: Negative
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  I Miss this Cutie Ry :( https://t.co/cUCqzzhIbY
# Base Sentiment:  Negative
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  0
# Negative Class:  5
# Pridicted Sentiment is: Negative
#
# Calculation based on 20 nearest neighbors
# Positive Class:  0
# Negative Class:  20
# Pridicted Sentiment is: Negative
#
# Calculation based on 50 nearest neighbors
# Positive Class:  0
# Negative Class:  50
# Pridicted Sentiment is: Negative
#
# Calculation based on 100 nearest neighbors
# Positive Class:  0
# Negative Class:  100
# Pridicted Sentiment is: Negative
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  im so sure fany is so happy now :(
# Base Sentiment:  Negative
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  0
# Negative Class:  5
# Pridicted Sentiment is: Negative
#
# Calculation based on 20 nearest neighbors
# Positive Class:  0
# Negative Class:  20
# Pridicted Sentiment is: Negative
#
# Calculation based on 50 nearest neighbors
# Positive Class:  0
# Negative Class:  50
# Pridicted Sentiment is: Negative
#
# Calculation based on 100 nearest neighbors
# Positive Class:  0
# Negative Class:  100
# Pridicted Sentiment is: Negative
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  I'm really trying hard to level up my working-on-a-tight-schedule art for comics, &amp; I know sometimes the art looks off, but :( ganbarimasu
# Base Sentiment:  Negative
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  0
# Negative Class:  5
# Pridicted Sentiment is: Negative
#
# Calculation based on 20 nearest neighbors
# Positive Class:  0
# Negative Class:  20
# Pridicted Sentiment is: Negative
#
# Calculation based on 50 nearest neighbors
# Positive Class:  0
# Negative Class:  50
# Pridicted Sentiment is: Negative
#
# Calculation based on 100 nearest neighbors
# Positive Class:  0
# Negative Class:  100
# Pridicted Sentiment is: Negative
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  @tv3midday Aw no.... was just about to switch over :-(
# Base Sentiment:  Negative
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  0
# Negative Class:  5
# Pridicted Sentiment is: Negative
#
# Calculation based on 20 nearest neighbors
# Positive Class:  0
# Negative Class:  20
# Pridicted Sentiment is: Negative
#
# Calculation based on 50 nearest neighbors
# Positive Class:  0
# Negative Class:  50
# Pridicted Sentiment is: Negative
#
# Calculation based on 100 nearest neighbors
# Positive Class:  0
# Negative Class:  100
# Pridicted Sentiment is: Negative
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  @CFVUF We hope it helped! :-)
# Base Sentiment:  Positive
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  5
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 20 nearest neighbors
# Positive Class:  20
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 50 nearest neighbors
# Positive Class:  50
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# Calculation based on 100 nearest neighbors
# Positive Class:  100
# Negative Class:  0
# Pridicted Sentiment is: Positive
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  need rest badly :-(
# Base Sentiment:  Negative
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  0
# Negative Class:  5
# Pridicted Sentiment is: Negative
#
# Calculation based on 20 nearest neighbors
# Positive Class:  0
# Negative Class:  20
# Pridicted Sentiment is: Negative
#
# Calculation based on 50 nearest neighbors
# Positive Class:  0
# Negative Class:  50
# Pridicted Sentiment is: Negative
#
# Calculation based on 100 nearest neighbors
# Positive Class:  0
# Negative Class:  100
# Pridicted Sentiment is: Negative
#
# **********************************************************************************************
# *************************************** Base Information ***************************************
# Text of Tweet:  @GutterdogUK I am ashamed at my language :(!
# Base Sentiment:  Negative
# ================================
# Calculation based on 5 nearest neighbors
# Positive Class:  0
# Negative Class:  5
# Pridicted Sentiment is: Negative
#
# Calculation based on 20 nearest neighbors
# Positive Class:  0
# Negative Class:  20
# Pridicted Sentiment is: Negative
#
# Calculation based on 50 nearest neighbors
# Positive Class:  0
# Negative Class:  50
# Pridicted Sentiment is: Negative
#
# Calculation based on 100 nearest neighbors
# Positive Class:  0
# Negative Class:  100
# Pridicted Sentiment is: Negative
#
# **********************************************************************************************
